# %%
# !python train_5folds.py --cfg configs/vit_large_384.yaml
# Out:
# Namespace(cfg='configs/vit_large_384.yaml', ckpt_dir='checkpoints', frac=1, folds=[0, 1, 2, 3, 4])
# {'model_name': 'vit_large_patch14_clip_336.openai_ft_in12k_in1k', 'workers': 8, 'image_size': 384, 'batch_size': 96, 'init_lr': 1e-05, 'epochs': 15, 'mixup': True, 'ema_decay': 0.995, 'epochs_for_final_submission': 4}
# ****************************** Fold 0 ******************************
# TRAIN: 432799 | VALID: 209746
# Fold: 0 | Epoch 0 | train loss: 0.01922 | ema_val_auc: 0.78890
# val auc improved from 0.00000 to 0.78890 saving model to checkpoints/vit_large_patch14_clip_336.openai_ft_in12k_in1k_384_fold0.pt
# Fold: 0 | Epoch 1 | train loss: 0.01480 | ema_val_auc: 0.83162
# val auc improved from 0.78890 to 0.83162 saving model to checkpoints/vit_large_patch14_clip_336.openai_ft_in12k_in1k_384_fold0.pt
# Fold: 0 | Epoch 2 | train loss: 0.01295 | ema_val_auc: 0.84501
# val auc improved from 0.83162 to 0.84501 saving model to checkpoints/vit_large_patch14_clip_336.openai_ft_in12k_in1k_384_fold0.pt
# Fold: 0 | Epoch 3 | train loss: 0.01107 | ema_val_auc: 0.84901
# val auc improved from 0.84501 to 0.84901 saving model to checkpoints/vit_large_patch14_clip_336.openai_ft_in12k_in1k_384_fold0.pt
# Fold: 0 | Epoch 4 | train loss: 0.00955 | ema_val_auc: 0.85330
# val auc improved from 0.84901 to 0.85330 saving model to checkpoints/vit_large_patch14_clip_336.openai_ft_in12k_in1k_384_fold0.pt
# Fold: 0 | Epoch 5 | train loss: 0.00840 | ema_val_auc: 0.84683
# Fold: 0 | Epoch 6 | train loss: 0.00728 | ema_val_auc: 0.84193
# Fold: 0 | Epoch 7 | train loss: 0.00632 | ema_val_auc: 0.84076
# Fold: 0 | Epoch 8 | train loss: 0.00570 | ema_val_auc: 0.84728
# Fold: 0 | Epoch 9 | train loss: 0.00526 | ema_val_auc: 0.84020
# Fold: 0 | Epoch 10 | train loss: 0.00499 | ema_val_auc: 0.84104
# Fold: 0 | Epoch 11 | train loss: 0.00473 | ema_val_auc: 0.83974
# Fold: 0 | Epoch 12 | train loss: 0.00479 | ema_val_auc: 0.83999
# Fold: 0 | Epoch 13 | train loss: 0.00472 | ema_val_auc: 0.83966
# Fold: 0 | Epoch 14 | train loss: 0.00478 | ema_val_auc: 0.84012
# ****************************** Fold 1 ******************************
# TRAIN: 444376 | VALID: 198113
# Fold: 1 | Epoch 0 | train loss: 0.01831 | ema_val_auc: 0.80092
# val auc improved from 0.00000 to 0.80092 saving model to checkpoints/vit_large_patch14_clip_336.openai_ft_in12k_in1k_384_fold1.pt
# Fold: 1 | Epoch 1 | train loss: 0.01399 | ema_val_auc: 0.84485
# val auc improved from 0.80092 to 0.84485 saving model to checkpoints/vit_large_patch14_clip_336.openai_ft_in12k_in1k_384_fold1.pt
# Fold: 1 | Epoch 2 | train loss: 0.01208 | ema_val_auc: 0.86349
# val auc improved from 0.84485 to 0.86349 saving model to checkpoints/vit_large_patch14_clip_336.openai_ft_in12k_in1k_384_fold1.pt
# Fold: 1 | Epoch 3 | train loss: 0.01061 | ema_val_auc: 0.85878
# Fold: 1 | Epoch 4 | train loss: 0.00906 | ema_val_auc: 0.86082
# Fold: 1 | Epoch 5 | train loss: 0.00800 | ema_val_auc: 0.86380
# val auc improved from 0.86349 to 0.86380 saving model to checkpoints/vit_large_patch14_clip_336.openai_ft_in12k_in1k_384_fold1.pt
# Fold: 1 | Epoch 6 | train loss: 0.00695 | ema_val_auc: 0.85981
# Fold: 1 | Epoch 7 | train loss: 0.00609 | ema_val_auc: 0.85739
# Fold: 1 | Epoch 8 | train loss: 0.00557 | ema_val_auc: 0.85557
# Fold: 1 | Epoch 9 | train loss: 0.00514 | ema_val_auc: 0.84810
# Fold: 1 | Epoch 10 | train loss: 0.00478 | ema_val_auc: 0.85440
# Fold: 1 | Epoch 11 | train loss: 0.00464 | ema_val_auc: 0.85578
# Fold: 1 | Epoch 12 | train loss: 0.00450 | ema_val_auc: 0.85538
# Fold: 1 | Epoch 13 | train loss: 0.00436 | ema_val_auc: 0.85498
# Fold: 1 | Epoch 14 | train loss: 0.00422 | ema_val_auc: 0.85458
# ****************************** Fold 2 ******************************
# TRAIN: 434663 | VALID: 203375
# Fold: 2 | Epoch 0 | train loss: 0.01910 | ema_val_auc: 0.79506
# val auc improved from 0.00000 to 0.79506 saving model to checkpoints/vit_large_patch14_clip_336.openai_ft_in12k_in1k_384_fold2.pt
# Fold: 2 | Epoch 1 | train loss: 0.01445 | ema_val_auc: 0.83484
# val auc improved from 0.79506 to 0.83484 saving model to checkpoints/vit_large_patch14_clip_336.openai_ft_in12k_in1k_384_fold2.pt
# Fold: 2 | Epoch 2 | train loss: 0.01268 | ema_val_auc: 0.84733
# val auc improved from 0.83484 to 0.84733 saving model to checkpoints/vit_large_patch14_clip_336.openai_ft_in12k_in1k_384_fold2.pt
# Fold: 2 | Epoch 3 | train loss: 0.01089 | ema_val_auc: 0.84606
# Fold: 2 | Epoch 4 | train loss: 0.00928 | ema_val_auc: 0.84494
# Fold: 2 | Epoch 5 | train loss: 0.00813 | ema_val_auc: 0.84714
# Fold: 2 | Epoch 6 | train loss: 0.00708 | ema_val_auc: 0.84952
# val auc improved from 0.84733 to 0.84952 saving model to checkpoints/vit_large_patch14_clip_336.openai_ft_in12k_in1k_384_fold2.pt
# Fold: 2 | Epoch 7 | train loss: 0.00611 | ema_val_auc: 0.84812
# Fold: 2 | Epoch 8 | train loss: 0.00575 | ema_val_auc: 0.84607
# Fold: 2 | Epoch 9 | train loss: 0.00513 | ema_val_auc: 0.84200
# Fold: 2 | Epoch 10 | train loss: 0.00470 | ema_val_auc: 0.84417
# Fold: 2 | Epoch 11 | train loss: 0.00469 | ema_val_auc: 0.84544
# Fold: 2 | Epoch 12 | train loss: 0.00468 | ema_val_auc: 0.84671
# Fold: 2 | Epoch 13 | train loss: 0.00467 | ema_val_auc: 0.84798
# Fold: 2 | Epoch 14 | train loss: 0.00466 | ema_val_auc: 0.84925
# ****************************** Fold 3 ******************************
# TRAIN: 436565 | VALID: 207682
# Fold: 3 | Epoch 0 | train loss: 0.01886 | ema_val_auc: 0.79766
# val auc improved from 0.00000 to 0.79766 saving model to checkpoints/vit_large_patch14_clip_336.openai_ft_in12k_in1k_384_fold3.pt
# Fold: 3 | Epoch 1 | train loss: 0.01431 | ema_val_auc: 0.83635
# val auc improved from 0.79766 to 0.83635 saving model to checkpoints/vit_large_patch14_clip_336.openai_ft_in12k_in1k_384_fold3.pt
# Fold: 3 | Epoch 2 | train loss: 0.01241 | ema_val_auc: 0.85257
# val auc improved from 0.83635 to 0.85257 saving model to checkpoints/vit_large_patch14_clip_336.openai_ft_in12k_in1k_384_fold3.pt
# Fold: 3 | Epoch 3 | train loss: 0.01075 | ema_val_auc: 0.85164
# Fold: 3 | Epoch 4 | train loss: 0.00923 | ema_val_auc: 0.85743
# val auc improved from 0.85257 to 0.85743 saving model to checkpoints/vit_large_patch14_clip_336.openai_ft_in12k_in1k_384_fold3.pt
# Fold: 3 | Epoch 5 | train loss: 0.00809 | ema_val_auc: 0.85433
# Fold: 3 | Epoch 6 | train loss: 0.00713 | ema_val_auc: 0.85159
# Fold: 3 | Epoch 7 | train loss: 0.00613 | ema_val_auc: 0.84417
# Fold: 3 | Epoch 8 | train loss: 0.00561 | ema_val_auc: 0.84822
# Fold: 3 | Epoch 9 | train loss: 0.00515 | ema_val_auc: 0.84310
# Fold: 3 | Epoch 10 | train loss: 0.00487 | ema_val_auc: 0.84759
# Fold: 3 | Epoch 11 | train loss: 0.00470 | ema_val_auc: 0.85296
# Fold: 3 | Epoch 12 | train loss: 0.00471 | ema_val_auc: 0.85635
# Fold: 3 | Epoch 13 | train loss: 0.00456 | ema_val_auc: 0.85615
# Fold: 3 | Epoch 14 | train loss: 0.00441 | ema_val_auc: 0.85595
# ****************************** Fold 4 ******************************
# TRAIN: 430441 | VALID: 209895
# Fold: 4 | Epoch 0 | train loss: 0.01935 | ema_val_auc: 0.77601
# val auc improved from 0.00000 to 0.77601 saving model to checkpoints/vit_large_patch14_clip_336.openai_ft_in12k_in1k_384_fold4.pt
# Fold: 4 | Epoch 1 | train loss: 0.01459 | ema_val_auc: 0.81447
# val auc improved from 0.77601 to 0.81447 saving model to checkpoints/vit_large_patch14_clip_336.openai_ft_in12k_in1k_384_fold4.pt
# Fold: 4 | Epoch 2 | train loss: 0.01274 | ema_val_auc: 0.84073
# val auc improved from 0.81447 to 0.84073 saving model to checkpoints/vit_large_patch14_clip_336.openai_ft_in12k_in1k_384_fold4.pt
# Fold: 4 | Epoch 3 | train loss: 0.01095 | ema_val_auc: 0.84510
# val auc improved from 0.84073 to 0.84510 saving model to checkpoints/vit_large_patch14_clip_336.openai_ft_in12k_in1k_384_fold4.pt
# Fold: 4 | Epoch 4 | train loss: 0.00934 | ema_val_auc: 0.83873
# Fold: 4 | Epoch 5 | train loss: 0.00831 | ema_val_auc: 0.84840
# val auc improved from 0.84510 to 0.84840 saving model to checkpoints/vit_large_patch14_clip_336.openai_ft_in12k_in1k_384_fold4.pt
# Fold: 4 | Epoch 6 | train loss: 0.00723 | ema_val_auc: 0.84032
# Fold: 4 | Epoch 7 | train loss: 0.00627 | ema_val_auc: 0.84068
# Fold: 4 | Epoch 8 | train loss: 0.00571 | ema_val_auc: 0.83951
# Fold: 4 | Epoch 9 | train loss: 0.00532 | ema_val_auc: 0.83929
# Fold: 4 | Epoch 10 | train loss: 0.00499 | ema_val_auc: 0.83896
# Fold: 4 | Epoch 11 | train loss: 0.00463 | ema_val_auc: 0.83909
# Fold: 4 | Epoch 12 | train loss: 0.00476 | ema_val_auc: 0.83811
# Fold: 4 | Epoch 13 | train loss: 0.00475 | ema_val_auc: 0.83830
# Fold: 4 | Epoch 14 | train loss: 0.00474 | ema_val_auc: 0.83849

# %%
# !python eval_5folds.py --cfg configs/vit_large_384.yaml
# Out:
# Namespace(cfg='configs/vit_large_384.yaml', ckpt_dir='checkpoints', folds=[0, 1, 2, 3, 4], pred_dir='predictions', crop_ratio=1, hflip=False)
# {'model_name': 'vit_large_patch14_clip_336.openai_ft_in12k_in1k', 'workers': 8, 'image_size': 384, 'batch_size': 96, 'init_lr': 1e-05, 'epochs': 15, 'mixup': True, 'ema_decay': 0.995, 'epochs_for_final_submission': 4}
# ****************************** Fold 0 ******************************
# 100%|█████████████████████████████████████████| 870/870 [00:09<00:00, 93.25it/s]
# Fold 0 | auc_score 0.8533
# ****************************** Fold 1 ******************************
# 100%|█████████████████████████████████████████| 870/870 [00:08<00:00, 99.03it/s]
# Fold 1 | auc_score 0.8638
# ****************************** Fold 2 ******************************
# 100%|█████████████████████████████████████████| 869/869 [00:09<00:00, 96.25it/s]
# Fold 2 | auc_score 0.8495
# ****************************** Fold 3 ******************************
# 100%|█████████████████████████████████████████| 870/870 [00:09<00:00, 94.51it/s]
# Fold 3 | auc_score 0.8574
# ****************************** Fold 4 ******************************
# 100%|█████████████████████████████████████████| 869/869 [00:09<00:00, 93.17it/s]
# Fold 4 | auc_score 0.8484
# OOF | auc_score 0.8530

# %%
# !python train_5folds.py --cfg configs/eva_large_384.yaml
# Out:
# Namespace(cfg='configs/eva_large_384.yaml', ckpt_dir='checkpoints', frac=1, folds=[0, 1, 2, 3, 4])
# {'model_name': 'eva_large_patch14_336.in22k_ft_in22k_in1k', 'workers': 8, 'image_size': 384, 'batch_size': 96, 'init_lr': 1e-05, 'epochs': 15, 'mixup': True, 'ema_decay': 0.995, 'epochs_for_final_submission': 10}
# ****************************** Fold 0 ******************************
# TRAIN: 432799 | VALID: 209746
# Fold: 0 | Epoch 0 | train loss: 0.01853 | ema_val_auc: 0.80717
# val auc improved from 0.00000 to 0.80717 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold0.pt
# Fold: 0 | Epoch 1 | train loss: 0.01373 | ema_val_auc: 0.84523
# val auc improved from 0.80717 to 0.84523 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold0.pt
# Fold: 0 | Epoch 2 | train loss: 0.01188 | ema_val_auc: 0.85557
# val auc improved from 0.84523 to 0.85557 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold0.pt
# Fold: 0 | Epoch 3 | train loss: 0.01005 | ema_val_auc: 0.84875
# Fold: 0 | Epoch 4 | train loss: 0.00870 | ema_val_auc: 0.84658
# Fold: 0 | Epoch 5 | train loss: 0.00774 | ema_val_auc: 0.84225
# Fold: 0 | Epoch 6 | train loss: 0.00690 | ema_val_auc: 0.84110
# Fold: 0 | Epoch 7 | train loss: 0.00627 | ema_val_auc: 0.83989
# Fold: 0 | Epoch 8 | train loss: 0.00581 | ema_val_auc: 0.83357
# Fold: 0 | Epoch 9 | train loss: 0.00552 | ema_val_auc: 0.83899
# Fold: 0 | Epoch 10 | train loss: 0.00525 | ema_val_auc: 0.83736
# Fold: 0 | Epoch 11 | train loss: 0.00511 | ema_val_auc: 0.84033
# Fold: 0 | Epoch 12 | train loss: 0.00497 | ema_val_auc: 0.84330
# Fold: 0 | Epoch 13 | train loss: 0.00483 | ema_val_auc: 0.84627
# Fold: 0 | Epoch 14 | train loss: 0.00469 | ema_val_auc: 0.84924
# ****************************** Fold 1 ******************************
# TRAIN: 444376 | VALID: 198113
# Fold: 1 | Epoch 0 | train loss: 0.01779 | ema_val_auc: 0.80609
# val auc improved from 0.00000 to 0.80609 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold1.pt
# Fold: 1 | Epoch 1 | train loss: 0.01315 | ema_val_auc: 0.84199
# val auc improved from 0.80609 to 0.84199 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold1.pt
# Fold: 1 | Epoch 2 | train loss: 0.01119 | ema_val_auc: 0.85528
# val auc improved from 0.84199 to 0.85528 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold1.pt
# Fold: 1 | Epoch 3 | train loss: 0.00975 | ema_val_auc: 0.85923
# val auc improved from 0.85528 to 0.85923 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold1.pt
# Fold: 1 | Epoch 4 | train loss: 0.00833 | ema_val_auc: 0.85743
# Fold: 1 | Epoch 5 | train loss: 0.00746 | ema_val_auc: 0.86324
# val auc improved from 0.85923 to 0.86324 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold1.pt
# Fold: 1 | Epoch 6 | train loss: 0.00666 | ema_val_auc: 0.85830
# Fold: 1 | Epoch 7 | train loss: 0.00614 | ema_val_auc: 0.85119
# Fold: 1 | Epoch 8 | train loss: 0.00577 | ema_val_auc: 0.85356
# Fold: 1 | Epoch 9 | train loss: 0.00534 | ema_val_auc: 0.84814
# Fold: 1 | Epoch 10 | train loss: 0.00518 | ema_val_auc: 0.84710
# Fold: 1 | Epoch 11 | train loss: 0.00502 | ema_val_auc: 0.84606
# Fold: 1 | Epoch 12 | train loss: 0.00486 | ema_val_auc: 0.84502
# Fold: 1 | Epoch 13 | train loss: 0.00470 | ema_val_auc: 0.84398
# Fold: 1 | Epoch 14 | train loss: 0.00454 | ema_val_auc: 0.84294
# ****************************** Fold 2 ******************************
# TRAIN: 434663 | VALID: 203375
# Fold: 2 | Epoch 0 | train loss: 0.01839 | ema_val_auc: 0.81674
# val auc improved from 0.00000 to 0.81674 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold2.pt
# Fold: 2 | Epoch 1 | train loss: 0.01360 | ema_val_auc: 0.84739
# val auc improved from 0.81674 to 0.84739 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold2.pt
# Fold: 2 | Epoch 2 | train loss: 0.01167 | ema_val_auc: 0.84102
# Fold: 2 | Epoch 3 | train loss: 0.00996 | ema_val_auc: 0.84670
# Fold: 2 | Epoch 4 | train loss: 0.00870 | ema_val_auc: 0.85047
# val auc improved from 0.84739 to 0.85047 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold2.pt
# Fold: 2 | Epoch 5 | train loss: 0.00792 | ema_val_auc: 0.85316
# val auc improved from 0.85047 to 0.85316 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold2.pt
# Fold: 2 | Epoch 6 | train loss: 0.00705 | ema_val_auc: 0.85498
# val auc improved from 0.85316 to 0.85498 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold2.pt
# Fold: 2 | Epoch 7 | train loss: 0.00633 | ema_val_auc: 0.85107
# Fold: 2 | Epoch 8 | train loss: 0.00592 | ema_val_auc: 0.84834
# Fold: 2 | Epoch 9 | train loss: 0.00542 | ema_val_auc: 0.85024
# Fold: 2 | Epoch 10 | train loss: 0.00515 | ema_val_auc: 0.84759
# Fold: 2 | Epoch 11 | train loss: 0.00504 | ema_val_auc: 0.84946
# Fold: 2 | Epoch 12 | train loss: 0.00496 | ema_val_auc: 0.85016
# Fold: 2 | Epoch 13 | train loss: 0.00503 | ema_val_auc: 0.84993
# Fold: 2 | Epoch 14 | train loss: 0.00492 | ema_val_auc: 0.85002
# ****************************** Fold 3 ******************************
# TRAIN: 436565 | VALID: 207682
# Fold: 3 | Epoch 0 | train loss: 0.01814 | ema_val_auc: 0.80726
# val auc improved from 0.00000 to 0.80726 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold3.pt
# Fold: 3 | Epoch 1 | train loss: 0.01343 | ema_val_auc: 0.84569
# val auc improved from 0.80726 to 0.84569 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold3.pt
# Fold: 3 | Epoch 2 | train loss: 0.01148 | ema_val_auc: 0.85504
# val auc improved from 0.84569 to 0.85504 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold3.pt
# Fold: 3 | Epoch 3 | train loss: 0.00986 | ema_val_auc: 0.85978
# val auc improved from 0.85504 to 0.85978 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold3.pt
# Fold: 3 | Epoch 4 | train loss: 0.00854 | ema_val_auc: 0.85965
# Fold: 3 | Epoch 5 | train loss: 0.00771 | ema_val_auc: 0.84924
# Fold: 3 | Epoch 6 | train loss: 0.00679 | ema_val_auc: 0.85110
# Fold: 3 | Epoch 7 | train loss: 0.00608 | ema_val_auc: 0.85981
# val auc improved from 0.85978 to 0.85981 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold3.pt
# Fold: 3 | Epoch 8 | train loss: 0.00575 | ema_val_auc: 0.85745
# Fold: 3 | Epoch 9 | train loss: 0.00546 | ema_val_auc: 0.86034
# val auc improved from 0.85981 to 0.86034 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold3.pt
# Fold: 3 | Epoch 10 | train loss: 0.00513 | ema_val_auc: 0.86079
# val auc improved from 0.86034 to 0.86079 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold3.pt
# Fold: 3 | Epoch 11 | train loss: 0.00508 | ema_val_auc: 0.85849
# Fold: 3 | Epoch 12 | train loss: 0.00506 | ema_val_auc: 0.85917
# Fold: 3 | Epoch 13 | train loss: 0.00499 | ema_val_auc: 0.85916
# Fold: 3 | Epoch 14 | train loss: 0.00481 | ema_val_auc: 0.85973
# ****************************** Fold 4 ******************************
# TRAIN: 430441 | VALID: 209895
# Fold: 4 | Epoch 0 | train loss: 0.01865 | ema_val_auc: 0.79589
# val auc improved from 0.00000 to 0.79589 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold4.pt
# Fold: 4 | Epoch 1 | train loss: 0.01385 | ema_val_auc: 0.82371
# val auc improved from 0.79589 to 0.82371 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold4.pt
# Fold: 4 | Epoch 2 | train loss: 0.01197 | ema_val_auc: 0.83151
# val auc improved from 0.82371 to 0.83151 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold4.pt
# Fold: 4 | Epoch 3 | train loss: 0.01029 | ema_val_auc: 0.83766
# val auc improved from 0.83151 to 0.83766 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold4.pt
# Fold: 4 | Epoch 4 | train loss: 0.00886 | ema_val_auc: 0.83221
# Fold: 4 | Epoch 5 | train loss: 0.00800 | ema_val_auc: 0.83145
# Fold: 4 | Epoch 6 | train loss: 0.00726 | ema_val_auc: 0.83313
# Fold: 4 | Epoch 7 | train loss: 0.00646 | ema_val_auc: 0.83791
# val auc improved from 0.83766 to 0.83791 saving model to checkpoints/eva_large_patch14_336.in22k_ft_in22k_in1k_384_fold4.pt
# Fold: 4 | Epoch 8 | train loss: 0.00600 | ema_val_auc: 0.82636
# Fold: 4 | Epoch 9 | train loss: 0.00564 | ema_val_auc: 0.83295
# Fold: 4 | Epoch 10 | train loss: 0.00551 | ema_val_auc: 0.83087
# Fold: 4 | Epoch 11 | train loss: 0.00526 | ema_val_auc: 0.82808
# Fold: 4 | Epoch 12 | train loss: 0.00529 | ema_val_auc: 0.82789
# Fold: 4 | Epoch 13 | train loss: 0.00532 | ema_val_auc: 0.82770
# Fold: 4 | Epoch 14 | train loss: 0.00535 | ema_val_auc: 0.82751

# %%
# !python eval_5folds.py --cfg configs/eva_large_384.yaml
# Out:
# Namespace(cfg='configs/eva_large_384.yaml', ckpt_dir='checkpoints', folds=[0, 1, 2, 3, 4], pred_dir='predictions', crop_ratio=1, hflip=False)
# {'model_name': 'eva_large_patch14_336.in22k_ft_in22k_in1k', 'workers': 8, 'image_size': 384, 'batch_size': 96, 'init_lr': 1e-05, 'epochs': 15, 'mixup': True, 'ema_decay': 0.995, 'epochs_for_final_submission': 10}
# ****************************** Fold 0 ******************************
# 100%|█████████████████████████████████████████| 870/870 [00:09<00:00, 93.95it/s]
# Fold 0 | auc_score 0.8556
# ****************************** Fold 1 ******************************
# 100%|█████████████████████████████████████████| 870/870 [00:08<00:00, 99.22it/s]
# Fold 1 | auc_score 0.8632
# ****************************** Fold 2 ******************************
# 100%|█████████████████████████████████████████| 869/869 [00:09<00:00, 95.90it/s]
# Fold 2 | auc_score 0.8550
# ****************************** Fold 3 ******************************
# 100%|█████████████████████████████████████████| 870/870 [00:09<00:00, 94.83it/s]
# Fold 3 | auc_score 0.8608
# ****************************** Fold 4 ******************************
# 100%|█████████████████████████████████████████| 869/869 [00:09<00:00, 93.75it/s]
# Fold 4 | auc_score 0.8379
# OOF | auc_score 0.8505

# %%
# !python train.py --cfg configs/vit_large_384.yaml
# Out:
# Namespace(cfg='configs/vit_large_384.yaml', ckpt_dir='checkpoints', frac=1)
# {'model_name': 'vit_large_patch14_clip_336.openai_ft_in12k_in1k', 'workers': 8, 'image_size': 384, 'batch_size': 96, 'init_lr': 1e-05, 'epochs': 15, 'mixup': True, 'ema_decay': 0.995, 'epochs_for_final_submission': 4}
# TRAIN: 532587 | VALID: 23181
# Epoch 0 | train loss: 0.01806 | ema_val_auc: 0.80031
# Epoch 1 | train loss: 0.01406 | ema_val_auc: 0.86544
# Epoch 2 | train loss: 0.01223 | ema_val_auc: 0.85560
# Epoch 3 | train loss: 0.01057 | ema_val_auc: 0.86162
# Epoch 4 | train loss: 0.00919 | ema_val_auc: 0.85971
# Epoch 5 | train loss: 0.00795 | ema_val_auc: 0.85112
# Epoch 6 | train loss: 0.00684 | ema_val_auc: 0.86192
# Epoch 7 | train loss: 0.00605 | ema_val_auc: 0.85557
# Epoch 8 | train loss: 0.00557 | ema_val_auc: 0.84856
# Epoch 9 | train loss: 0.00505 | ema_val_auc: 0.86036
# Epoch 10 | train loss: 0.00466 | ema_val_auc: 0.85689
# Epoch 11 | train loss: 0.00460 | ema_val_auc: 0.85504
# Epoch 12 | train loss: 0.00439 | ema_val_auc: 0.85920
# Epoch 13 | train loss: 0.00418 | ema_val_auc: 0.86336
# Epoch 14 | train loss: 0.00397 | ema_val_auc: 0.86752

# %%
# !python train.py --cfg configs/eva_large_384.yaml
# Out:
# Namespace(cfg='configs/eva_large_384.yaml', ckpt_dir='checkpoints', frac=1)
# {'model_name': 'eva_large_patch14_336.in22k_ft_in22k_in1k', 'workers': 8, 'image_size': 384, 'batch_size': 96, 'init_lr': 1e-05, 'epochs': 15, 'mixup': True, 'ema_decay': 0.995, 'epochs_for_final_submission': 10}
# TRAIN: 532587 | VALID: 23181
# Epoch 0 | train loss: 0.01759 | ema_val_auc: 0.82467
# Epoch 1 | train loss: 0.01323 | ema_val_auc: 0.84435
# Epoch 2 | train loss: 0.01138 | ema_val_auc: 0.85863
# Epoch 3 | train loss: 0.00977 | ema_val_auc: 0.85387
# Epoch 4 | train loss: 0.00857 | ema_val_auc: 0.85931
# Epoch 5 | train loss: 0.00753 | ema_val_auc: 0.85906
# Epoch 6 | train loss: 0.00677 | ema_val_auc: 0.85227
# Epoch 7 | train loss: 0.00618 | ema_val_auc: 0.82299
# Epoch 8 | train loss: 0.00580 | ema_val_auc: 0.84869
# Epoch 9 | train loss: 0.00531 | ema_val_auc: 0.84158
# Epoch 10 | train loss: 0.00511 | ema_val_auc: 0.84471
# Epoch 11 | train loss: 0.00491 | ema_val_auc: 0.84784
# Epoch 12 | train loss: 0.00471 | ema_val_auc: 0.85097
# Epoch 13 | train loss: 0.00451 | ema_val_auc: 0.85410
# Epoch 14 | train loss: 0.00431 | ema_val_auc: 0.85723
