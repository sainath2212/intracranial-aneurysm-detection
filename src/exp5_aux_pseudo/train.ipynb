# %%
# !python train.py --cfg configs/mit_b4_fpn_384.yaml
# Out:
# Namespace(cfg='configs/mit_b4_fpn_384.yaml', ckpt_dir='checkpoints', frac=1, folds=[0, 1, 2, 3, 4])
# {'encoder_name': 'mit_b4', 'decoder_name': 'fpn', 'encoder_weights': 'imagenet', 'encoder_feat_dims': 1280, 'workers': 8, 'image_size': 384, 'batch_size': 112, 'init_lr': 0.0001, 'epochs': 15, 'mixup': True, 'ema_decay': 0.995}
# (932, 19) (142, 2)
# ****************************** Fold 0 ******************************
# TRAIN: 432799 | VALID: 209746
# Fold: 0 | Epoch 0 | train loss: 0.01319 | ema_val_auc: 0.78275
# val auc improved from 0.00000 to 0.78275 saving model to checkpoints/mit_b4_384_fold0.pt
# Fold: 0 | Epoch 1 | train loss: 0.00930 | ema_val_auc: 0.82130
# val auc improved from 0.78275 to 0.82130 saving model to checkpoints/mit_b4_384_fold0.pt
# Fold: 0 | Epoch 2 | train loss: 0.00816 | ema_val_auc: 0.82148
# val auc improved from 0.82130 to 0.82148 saving model to checkpoints/mit_b4_384_fold0.pt
# Fold: 0 | Epoch 3 | train loss: 0.00730 | ema_val_auc: 0.84205
# ...

# %%
# !python eval.py --cfg configs/mit_b4_fpn_384.yaml
# Out:
# Namespace(cfg='configs/mit_b4_fpn_384.yaml', ckpt_dir='checkpoints', folds=[0, 1, 2, 3, 4], pred_dir='predictions', crop_ratio=1, hflip=False)
# {'encoder_name': 'mit_b4', 'decoder_name': 'fpn', 'encoder_weights': 'imagenet', 'encoder_feat_dims': 1280, 'workers': 8, 'image_size': 384, 'batch_size': 112, 'init_lr': 0.0001, 'epochs': 15, 'mixup': True, 'ema_decay': 0.995}
# ****************************** Fold 0 ******************************
# Evaluating...
# 100%|█████████████████████████████████████████| 870/870 [00:09<00:00, 92.61it/s]
# Fold 0 | auc_score 0.8497
# ****************************** Fold 1 ******************************
# Evaluating...
# 100%|█████████████████████████████████████████| 870/870 [00:08<00:00, 97.76it/s]
# Fold 1 | auc_score 0.8560
# ****************************** Fold 2 ******************************
# Evaluating...
# 100%|█████████████████████████████████████████| 869/869 [00:09<00:00, 94.43it/s]
# Fold 2 | auc_score 0.8526
# ...
